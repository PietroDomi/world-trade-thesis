# %%
import os

colab = True
# #### COLAB ONLY CELL
if colab:
    from google.colab import drive
    drive.mount('/content/gdrive')
    # drive.mount('/content/gdrive',force_remount=True)
    os.chdir("/content/gdrive/MyDrive/COMEXT/data-samples")
    # !pip install -q -r ../world-trade-thesis/requirements.txt
    # !pwd
else:
    os.chdir("H:/My Drive/COMEXT/data-samples")
    # !pwd
import pandas as pd
from tqdm.notebook import tqdm
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/COMEXT/data-samples

# %% [markdown]
# # Bulk download

# %%
# %%shell

# for i in {2010..2021}
# do 
#     echo "tr_intra_/tr_intra_${i}52.7z"
#     wget -O "./tr_intra_/tr_intra_${i}52.7z" "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2FCOMEXT_DATA%2FTRANSPORT_INTRA%2Ftr_intra_${i}52.7z"
#     7z x -o"./tr_intra_/" "./tr_intra_/tr_intra_${i}52.7z"
#     rm -v "./tr_intra_/tr_intra_${i}52.7z"
# done

# for y in {2010..2021}
# do
#     for m in {1..12}
#     do  
#         s=$((100*$y +$m))
#         echo $s
#         echo "./tr_intra_/tr_intra_${s}.7z"
#         wget -O "tr_intra_/tr_intra_${s}.7z" "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2FCOMEXT_DATA%2FTRANSPORT_INTRA%2Ftr_intra_${s}.7z"
#         7z x -o"./tr_intra_/" "./tr_intra_/tr_intra_${s}.7z"
#         rm -v "./tr_intra_/tr_intra_${s}.7z"
#     done
# done

# %%
# for f in tqdm(os.listdir("./tr_intra_")):
#     if "parquet" not in f:
#         try:
#             pd.read_csv(f"./tr_intra_/{f}",na_filter=False).to_parquet(f"./tr_intra_/{f.replace('.dat','.parquet')}")
#             os.system(f'rm -v "./tr_intra_/{f}"') 
#         except:
#             print(f)

# %%
# %%shell
# # # prog() {
# # #     local w=80 p=$1;  shift
# # #     # create a string of spaces, then change them to dots
# # #     printf -v dots "%*s" "$(( $p*$w/100 ))" ""; dots=${dots// /.};
# # #     # print those dots on a fixed-width space plus the percentage etc.
# # #     printf "\r\e[K|%-*s| %3d %% %s" "$w" "$dots" "$p" "$*";
# # # }
#
# # for i in {2001..2021}
# # do
# #     # prog "$i" still working...
# #     echo "full/full${i}52.7z"
# #     wget -O "./full/full${i}52.7z" "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2Fbulk_download%2FCOMEXT_DATA%2FPRODUCTS%2Ffull${i}52.7z"
# #     # 7z x -o"./full/" "./full/full${i}52.7z"
# #     # rm -v "./full/full${i}52.7z"
# # done
#
#
# for y in {2021..2021}
# do
#     # prog "$y" still working...
#     for m in {1..12}
#     do
#         s=$((100*$y +$m))
#         echo $s
#         echo "./full/full${s}.7z"
#         wget -O "./full/full${s}.7z" "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2Fbulk_download%2FCOMEXT_DATA%2FPRODUCTS%2Ffull${s}.7z"
#         # 7z x -o"./full/" "./full/full${s}.7z"
#         # rm -v "./full/full${s}.7z"
#     done
# done
#
# for y in {2020..2020}
# do
#     # prog "$y" still working...
#     for m in {9..12}
#     do
#         s=$((100*$y +$m))
#         echo $s
#         echo "./full/full${s}.7z"
#         wget -O "./full/full${s}.7z" "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2Fbulk_download%2FCOMEXT_DATA%2FPRODUCTS%2Ffull${s}.7z"
#         # 7z x -o"./full/" "./full/full${s}.7z"
#         # rm -v "./full/full${s}.7z"
#     done
# done
# Out:
# 202101
# ./full/full202101.7z
# --2022-08-02 15:34:35--  https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2Fbulk_download%2FCOMEXT_DATA%2FPRODUCTS%2Ffull202101.7z
# Resolving ec.europa.eu (ec.europa.eu)... 147.67.34.30, 147.67.210.30, 2a01:7080:24:100::666:30, ...
# Connecting to ec.europa.eu (ec.europa.eu)|147.67.34.30|:443... connected.
# HTTP request sent, awaiting response... 200
# Cookie coming from ec.europa.eu attempted to set domain to europa.eu/eurostat
# Length: 33945626 (32M) [application/octet-stream]
# Saving to: ‘./full/full202101.7z’
#
# ./full/full202101.7 100%[===================>]  32.37M   171KB/s    in 3m 32s
#
# 2022-08-02 15:38:08 (156 KB/s) - ‘./full/full202101.7z’ saved [33945626/33945626]
#
# 202102
# ./full/full202102.7z
# --2022-08-02 15:38:08--  https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2Fbulk_download%2FCOMEXT_DATA%2FPRODUCTS%2Ffull202102.7z
# ...

# %%
for f in tqdm(os.listdir("./full")):
    if "7z" in f:
        if "52" in f:
            try:
                os.system(f'7z x -o"./full/" "./full/{f}"')
                os.system(f'rm -v "./full/{f}"')
                pd.read_csv(f'./full/{f.replace("7z","dat")}',encoding="latin",na_filter=False).to_parquet(f"./full/Years/{f.replace('.7z','.parquet')}")
                os.system(f'rm -v "./full/{f.replace("7z","dat")}"') 
            except:
                print(f)
        else:
            try:
                os.system(f'7z x -o"./full/" "./full/{f}"')
                os.system(f'rm -v "./full/{f}"')
                pd.read_csv(f'./full/{f.replace("7z","dat")}',encoding="latin",na_filter=False).to_parquet(f"./full/Months/{f.replace('.7z','.parquet')}")
                os.system(f'rm -v "./full/{f.replace("7z","dat")}"')
            except:
                print(f)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
# f = "full200752.dat"
# pd.read_csv(f"./full/{f}",encoding="latin",na_filter=False,low_memory=False).to_parquet(f"./full/Months/{f.replace('.dat','.parquet')}")

# %%
# %%shell

# for i in {2010..2021}
# do 
#     echo "tr/tr${i}52.7z"
#     wget -O "./tr/tr${i}52.7z" "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2Fbulk_download%2FCOMEXT_DATA%2FTRANSPORT_NSTR%2Ftr${i}52.7z"
#     # 7z x -o"./tr/" "./tr/tr${i}52.7z"
#     # rm -v "./tr/tr${i}52.7z"
# done

# for y in {2010..2021}
# do
#     for m in {1..12}
#     do  
#         s=$((100*$y +$m))
#         echo $s
#         echo "./tr/tr${s}.7z"
#         wget -O "tr/tr${s}.7z" "https://ec.europa.eu/eurostat/estat-navtree-portlet-prod/BulkDownloadListing?sort=1&file=comext%2Fbulk_download%2FCOMEXT_DATA%2FTRANSPORT_NSTR%2Ftr${s}.7z"
#         # 7z x -o"./tr/" "./tr/tr${s}.7z"
#         # rm -v "./tr/tr${s}.7z"
#     done
# done

# %%
# for f in tqdm(os.listdir("./tr")):
#     if "7z" in f:
#         if "52" in f:
#             try:
#                 os.system(f'7z x -o"./tr/" "./tr/{f}"')
#                 os.system(f'rm -v "./tr/{f}"')
#                 pd.read_csv(f'./tr/{f.replace("7z","dat")}',encoding="latin",low_memory=False,na_filter=False).to_parquet(f"./tr/Years/{f.replace('.7z','.parquet')}")
#                 os.system(f'rm -v "./tr/{f.replace("7z","dat")}"') 
#             except:
#                 print(f)
#         else:
#             try:
#                 os.system(f'7z x -o"./tr/" "./tr/{f}"')
#                 os.system(f'rm -v "./tr/{f}"')
#                 pd.read_csv(f'./tr/{f.replace("7z","dat")}',encoding="latin",low_memory=False,na_filter=False).to_parquet(f"./tr/Months/{f.replace('.7z','.parquet')}")
#                 os.system(f'rm -v "./tr/{f.replace("7z","dat")}"') 
#             except:
#                 print(f)

# %% [markdown]
# # 7z compress

# %%
# %%shell
## Compressing
# 7z a comext.7z ./COMEXT/*

# %%
# %%shell
# 7z l comext.7z

# %% [markdown]
# # Manual cleaning

# %%
# for f in tqdm(os.listdir("full")):
#     if "columns" in f:
#         os.system("rm full/"+f)

# %%
# os.listdir("full")

# %% [markdown]
# # Population

# %%
# un_df = pd.read_csv("./data-samples/population/WPP2022_TotalPopulationBySex.csv",na_filter=False)
# un_df_pivot = un_df[(un_df.ISO2_code != "")&(un_df.Time <= 2022)&(un_df.Variant == "Medium")]\
#                      .set_index(['LocID', 'ISO3_code', 'ISO2_code', 'SDMX_code','Location'])\
#                      [["Time","PopTotal"]].pivot(columns=["Time"]).droplevel(-2,axis=1).reset_index()
# un_df_pivot.rename({"ISO3_code":"iso3","Location":"Country","ISO2_code":"iso2"},axis=1).to_csv("./data-samples/population/df_pop.csv")
